# %% [markdown]
# <a href="https://colab.research.google.com/github/pvs560/GenAI_Python_AI_Learning/blob/main/My_firstprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print "hello"
# Out:
#   File "/tmp/ipykernel_1176/2253489653.py", line 1
#     print "hello"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
name = "vidya"
age = 48
percentage = 72.12

# %%
marks = [85, 90, 78]
subjects = {"python", "sql", "Java"}

# %%
python = 85
sql = 90
Java = 78

# %%
total = python + sql + Java

# %%
print(total)
# Out:
# 253

# %%
percentage = total/300*100

# %%
print(percentage)
# Out:
# 84.33333333333334

# %%
percentage >= 75
# Out:
# True

# %%
if percentage >= 75 :
  print("distinction");
  print('test');
elif percentage >= 60 and percentage < 75 :
  print("First Class")
else: print("Second Class")
# Out:
# distinction
# test

# %%
percentage = 80

# %%
name = "vidya"
college = "RGM"
course = "CSE"

# %%
name
# Out:
# 'vidya'

# %%
name[0]
# Out:
# 'v'

# %%
len(name)
# Out:
# 5

# %%
name = "    fdfdfd"

# %%
name
# Out:
# '    fdfdfd'

# %%
len(name)
# Out:
# 10

# %%
name.lstrip()
# Out:
# 'fdfdfd'

# %%
name
# Out:
# '    fdfdfd'

# %%
name.islower()
# Out:
# True

# %%
name.casefold
# Out:
# <function str.casefold()>

# %%
type(name)
# Out:
# str

# %%
marks = {}

# %%
type(marks)
# Out:
# dict

# %%
marks = { 'a': 1, 'b': 2}

# %%
marks
# Out:
# {'a': 1, 'b': 2}

# %%
type(marks)
# Out:
# dict

# %%
marks = [85, 70, 90, 55, 70, 50, 90]

# %%
marks[0]
# Out:
# 85

# %%
len(marks)
# Out:
# 3

# %%
marks
# Out:
# [85, 70, 90, 55, 70, 50, 90]

# %%
vb = marks

# %%
vb
# Out:
# [85, 70, 90, 55, 70, 50, 90]

# %%
vb.append(99)

# %%
vb
# Out:
# [85, 70, 90, 55, 70, 50, 90, 99]

# %%
marks
# Out:
# [85, 70, 90, 55, 70, 50, 90, 99]

# %%
marks.pop()
# Out:
# 99

# %%
vb
# Out:
# [85, 70, 90, 55, 70, 50, 90]

# %%
vb, marks
# Out:
# ([85, 70, 90, 55, 70, 50, 90], [85, 70, 90, 55, 70, 50, 90])

# %%
type(vb) == list
# Out:
# True

# %%
marks.insert(1, 100)

# %%
marks
# Out:
# [85, 100, 70, 90, 55, 70, 50, 90]

# %%
marks
# Out:
# [85, 100, 90, 55, 70, 50, 90]

# %%
marks.reverse()

# %%
marks
# Out:
# [90, 50, 70, 90, 100, 85]

# %%
marks.insert(2,
             12)

# %%
marks
# Out:
# [90, 50, 12, 12, 70, 90, 100, 85]

# %%
#tupples
#dect
#sets

college_location = (20.25, 24.25)

# %%
type(college_location)
# Out:
# tuple

# %%
vb =()

# %%
vb
# Out:
# ()

# %%
type(vb)
# Out:
# tuple

# %%
vb = (2)*3

# %%
vb = (2*2, 'ui')

# %%
vb
# Out:
# (4, 'ui')

# %%
type(vb)
# Out:
# tuple

# %%
type(vb[1]) == str
# Out:
# True

# %%
student = {'name': 'vidya', 'age': 30, 'percentage': 80}

# %%
student
# Out:
# {'name': 'vidya', 'age': 30, 'percentage': 80}

# %%
student.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1247/2728737192.py in <cell line: 0>()
# ----> 1 student.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
student['name']
# Out:
# 'vidya'

# %%
student['age']
# Out:
# 30

# %%
student['college'] = "RGM"

# %%
student
# Out:
# {'name': 'vidya', 'age': 30, 'percentage': 80}

# %%
del student['college']

# %%
student1 = { 'name': 'vidya', 'age': 30, 'percentage': 80, 'marks': [40,80,90,90,50] }

# %%
student1
# Out:
# {'name': 'vidya', 'age': 30, 'percentage': 80, 'marks': [40, 80, 90, 90, 50]}

# %%
#SETS
subjects = ["python", "Java", "Sql", "Javascript", "python", 25]

# %%
subjects
# Out:
# ['python', 'Java', 'Sql', 'Javascript', 'python', 25]

# %%
unique_subjects = set(subjects)

# %%
unique_subjects
# Out:
# {25, 'Java', 'Javascript', 'Sql', 'python'}

# %%
type(unique_subjects)
# Out:
# set

# %%
unique_subjects.add("Physics")

# %%
unique_subjects
# Out:
# {25, 'Java', 'Javascript', 'Physics', 'Sql', 'python'}

# %%
unique_subjects
# Out:
# {25, 'Java', 'Javascript', 'Physics', 'Sql', 'python'}

# %%
unique_subjects.
