# %% [markdown]
# <a href="https://colab.research.google.com/github/pvs560/GenAI_Python_AI_Learning/blob/main/My_firstprogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
